# %% [markdown]
# <a href="https://colab.research.google.com/github/shyamsundar-v/ML-CLASSIFICATION/blob/main/ANDRIOD_AUTHENTICITY_PREDICTION_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This dataset consists of apps needed permissions during installation and run-time. We collect apps from three different sources google play, third-party apps and malware dataset. This file contains more than 30,000 Android apps. features extracted at the time of installation and execution. One file contains the name of the features and others contain .apk file corresponding to it extracted permissions with respective package. Apps are collected from Google's play store, hiapk, app china,  Android,  mumayi , gfan  slideme, and pandaapp.  These .apk files collected from the last three years continuously and contain 81 distinct malware families. But, Here you are only supposed to predict whether the app is benign(0) or malware(1).

# %% [markdown]
# # **Attribute Information**

# %% [markdown]
# 1 . App :- Name of the App
#
# 2 . Package :- OBB/Data package installed in root folder
#
# 3 . Category :-  App Category (eg. Entertainment, Adventure, puzzle, Action, Antivirus, etc.)
#
# 4 . Description :- App Description
#
# 5 . Rating :-  Rating out of 5
#
# 6 . Number of ratings :- No. of Ratings given by users
#
# 7 . Price :- Price of the App
#
# 8 . Related apps :-  Apps related to installed App
#
# 9 . Dangerous **(D)** permissions count :- No. of Dangerous Permissions allowed by user
#
# 10 . Safe **(S)** permissions count :- No. of Safe Permissions allowed by user
#
# 11 . Default : Access DRM content. (S) :- 0 : No , 1 : Yes
#
# 12 . Default : Access Email provider data (S) :- 0 : No , 1 : Yes
#
# 13 . Default : Access all system downloads (S) :- 0 : No , 1 : Yes
#
# 14 . Default : Access download manager. (S) :- 0 : No , 1 : Yes
#
# 15 . Default : Advanced download manager functions. (S) :- 0 : No , 1 : Yes
#
# 16 . Default : Audio File Access (S) :- 0 : No , 1 : Yes
#
# 17 . Default : Install DRM content. (S) :- 0 : No , 1 : Yes
#
# 18 . Default : Modify Google service configuration (S) :- 0 : No , 1 : Yes
#
# 19 . Default : Modify Google settings (S) :- 0 : No , 1 : Yes
#
# 20 . Default : Move application resources (S) :- 0 : No , 1 : Yes
#
# 21 . Default : Read Google settings (S) :- 0 : No , 1 : Yes
#
# 22 . Default : Send download notifications. (S) :- 0 : No , 1 : Yes
#
# 23 . Default : Voice Search Shortcuts (S) :- 0 : No , 1 : Yes
#
# 24 . Default : access SurfaceFlinger (S) :- 0 : No , 1 : Yes
#
# 25 . Default : access checkin properties (S) :- 0 : No , 1 : Yes
#
# 26 . Default : access the cache filesystem (S) :- 0 : No , 1 : Yes
#
# 27 . Default : access to passwords for Google accounts (S) :- 0 : No , 1 : Yes
#
# 28 . Default : act as an account authenticator (S) :- 0 : No , 1 : Yes
#
# 29 . Default : bind to a wallpaper (S) :- 0 : No , 1 : Yes
#
# 30 . Default : bind to an input method (S) :- 0 : No , 1 : Yes
#
# 31 . Default : change screen orientation (S) :- 0 : No , 1 : Yes
#
# 32 . Default : coarse (network-based) location (S) :- 0 : No , 1 : Yes
#
# 33 . Default : control location update notifications (S) :- 0 : No , 1 : Yes
#
# 34 . Default : control system backup and restore (S) :- 0 : No , 1 : Yes
#
# 35 . Default : delete applications (S) :- 0 : No , 1 : Yes
#
# 36 . Default : delete other applications' caches (S) :- 0 : No , 1 : Yes
#
# 37 . Default : delete other applications' data (S) :- 0 : No , 1 : Yes
#
# 38 . Default : directly call any phone numbers (S) :- 0 : No , 1 : Yes
#
# 39 . Default : directly install applications (S) :- 0 : No , 1 : Yes
#
# 40 . Default : disable or modify status bar (S) :- 0 : No , 1 : Yes
#
# 41 . Default : discover known accounts (S) :- 0 : No , 1 : Yes
#
# 42 . Default : display unauthorized windows (S) :- 0 : No , 1 : Yes
#
# 43 . Default : enable or disable application components (S) :- 0 : No , 1 : Yes
#
# 44 . Default : force application to close (S) :- 0 : No , 1 : Yes
#
# 45 . Default : force device reboot (S) :- 0 : No , 1 : Yes
#
# 46 . Default : full Internet access (S) :- 0 : No , 1 : Yes
#
# 47 . Default : interact with a device admin (S) :- 0 : No , 1 : Yes
#
# 48 . Default : manage application tokens (S) :- 0 : No , 1 : Yes
#
# 49 . Default : mock location sources for testing (S) :- 0 : No , 1 : Yes
#
# 50 . Default : modify battery statistics (S) :- 0 : No , 1 : Yes
#
# 51 . Default : modify secure system settings (S) :- 0 : No , 1 : Yes
#
# 52 . Default : modify the Google services map (S) :- 0 : No , 1 : Yes
#
# 53 . Default : modify/delete USB storage contents modify/delete SD card contents (S) :- 0 : No , 1 : Yes
#
# 54 . Default : monitor and control all application launching (S) :- 0 : No , 1 : Yes
#
# 55 . Default : partial shutdown (S) :- 0 : No , 1 : Yes
#
# 56 . Default : permanently disable device (S) :- 0 : No , 1 : Yes
#
# 57 . Default : permission to install a location provider (S) :- 0 : No , 1 : Yes
#
# 58 . Default : power device on or off (S) :- 0 : No , 1 : Yes
#
# 59 . Default : press keys and control buttons (S) :- 0 : No , 1 : Yes
#
# 60 . Default : prevent app switches (S) :- 0 : No , 1 : Yes
#
# 61 . Default : read frame buffer (S) :- 0 : No , 1 : Yes
#
# 62 . Default : read instant messages (S) :- 0 : No , 1 : Yes
#
# 63 . Default : read phone state and identity (S) :- 0 : No , 1 : Yes
#
# 64 . Default : record what you type and actions you take (S) :- 0 : No , 1 : Yes
#
# 65 . Default : reset system to factory defaults (S) :- 0 : No , 1 : Yes
#
# 66 . Default : run in factory test mode (S) :- 0 : No , 1 : Yes
#
# 67 . Default : set time (S) :- 0 : No , 1 : Yes
#
# 68 . Default : set wallpaper size hints (S) :- 0 : No , 1 : Yes
#
# 69 . Default : start IM service (S) :- 0 : No , 1 : Yes
#
# 70 . Default : update component usage statistics (S) :- 0 : No , 1 : Yes
#
# 71 . Default : write contact data (S) :- 0 : No , 1 : Yes
#
# 72 . Default : write instant messages (S) :- 0 : No , 1 : Yes
#
# 73 . Development tools : enable application debugging (D) :- 0 : No , 1 : Yes
#
# 74 . Development tools : limit number of running processes (D) :- 0 : No , 1 : Yes
#
# 75 . Development tools : make all background applications close (D) :- 0 : No , 1 : Yes
#
# 76 . Development tools : send Linux signals to applications (D) :- 0 : No , 1 : Yes
#
# 77 . Hardware controls : change your audio settings (D) :- 0 : No , 1 : Yes
#
# 78 . Hardware controls : control flashlight (S) :- 0 : No , 1 : Yes
#
# 79 . Hardware controls : control vibrator (S) :- 0 : No , 1 : Yes
#
# 80 . Hardware controls : record audio (D) :- 0 : No , 1 : Yes
#
# 81 . Hardware controls : take pictures and videos (D) :- 0 : No , 1 : Yes
#
# 82 . Hardware controls : test hardware (S) :- 0 : No , 1 : Yes
#
# 83 . Network communication : Broadcast data messages to applications. (S) :- 0 : No , 1 : Yes
#
# 84 . Network communication : control Near Field Communication (D) :- 0 : No , 1 : Yes
#
# 85 . Network communication : create Bluetooth connections (D) :- 0 : No , 1 : Yes
#
# 86 . Network communication : download files without notification (S) :- 0 : No , 1 : Yes
#
# 87 . Network communication : full Internet access (D) :- 0 : No , 1 : Yes
#
# 88 . Network communication : make/receive Internet calls (D) :- 0 : No , 1 : Yes
#
# 89 . Network communication : receive data from Internet (S) :- 0 : No , 1 : Yes
#
# 90 . Network communication : view Wi-Fi state (S) :- 0 : No , 1 : Yes
#
# 91 . Network communication : view network state (S) :- 0 : No , 1 : Yes
#
# 92 . Phone calls : intercept outgoing calls (D) :- 0 : No , 1 : Yes
#
# 93 . Phone calls : modify phone state (S) :- 0 : No , 1 : Yes
#
# 94 . Phone calls : read phone state and identity (D) :- 0 : No , 1 : Yes
#
# 95 . Services that cost you money : directly call phone numbers (D) :- 0 : No , 1 : Yes
#
# 96 . Services that cost you money : send SMS messages (D) :- 0 : No , 1 : Yes
#
# 97 . Storage : modify/delete USB storage contents modify/delete SD card contents (D) :- 0 : No , 1 : Yes
#
# 98 . System tools : allow Wi-Fi Multicast reception (D) :- 0 : No , 1 : Yes
#
# 99 . System tools : automatically start at boot (S) :- 0 : No , 1 : Yes
#
# 100 . System tools : bluetooth administration (D) :- 0 : No , 1 : Yes
#
# 101 . System tools : change Wi-Fi state (D) :- 0 : No , 1 : Yes
#
# 102 . System tools : change background data usage setting (S) :- 0 : No , 1 : Yes
#
# 103 . System tools : change network connectivity (D) :- 0 : No , 1 : Yes
#
# 104 . System tools : change your UI settings (D) :- 0 : No , 1 : Yes
#
# 105 . System tools : delete all application cache data (D) :- 0 : No , 1 : Yes
#
# 106 . System tools : disable keylock (D) :- 0 : No , 1 : Yes
#
# 107 . System tools : display system-level alerts (D) :- 0 : No , 1 : Yes
#
# 108 . System tools : expand/collapse status bar (S) :- 0 : No , 1 : Yes
#
# 109 . System tools : force stop other applications (S) :- 0 : No , 1 : Yes
#
# 110 . System tools : format external storage (D) :- 0 : No , 1 : Yes
#
# 111 . System tools : kill background processes (S) :- 0 : No , 1 : Yes
#
# 112 . System tools : make application always run (D) :- 0 : No , 1 : Yes
#
# 113 . System tools : measure application storage space (S) :- 0 : No , 1 : Yes
#
# 114 . System tools : modify global animation speed (D) :- 0 : No , 1 : Yes
#
# 115 . System tools : modify global system settings (D) :- 0 : No , 1 : Yes
#
# 116 . System tools : mount and unmount filesystems (D) :- 0 : No , 1 : Yes
#
# 117 . System tools : prevent device from sleeping (D) :- 0 : No , 1 : Yes
#
# 118 . System tools : read subscribed feeds (S) :- 0 : No , 1 : Yes
#
# 119 . System tools : read sync settings (S) :- 0 : No , 1 : Yes
#
# 120 . System tools : read sync statistics (S) :- 0 : No , 1 : Yes
#
# 121 . System tools : read/write to resources owned by diag (S) :- 0 : No , 1 : Yes
#
# 122 . System tools : reorder running applications (D) :- 0 : No , 1 : Yes
#
# 123 . System tools : retrieve running applications (D) :- 0 : No , 1 : Yes
#
# 124 . System tools : send package removed broadcast (S) :- 0 : No , 1 : Yes
#
# 125 . System tools : send sticky broadcast (S) :- 0 : No , 1 : Yes
#
# 126 . System tools : set preferred applications (S) :- 0 : No , 1 : Yes
#
# 127 . System tools : set time zone (D) :- 0 : No , 1 : Yes
#
# 128 . System tools : set wallpaper (S) :- 0 : No , 1 : Yes
#
# 129 . System tools : set wallpaper size hints (S) :- 0 : No , 1 : Yes
#
# 130 . System tools : write Access Point Name settings (D) :- 0 : No , 1 : Yes
#
# 131 . System tools : write subscribed feeds (D) :- 0 : No , 1 : Yes
#
# 132 . System tools : write sync settings (D) :- 0 : No , 1 : Yes
#
# 133 . Your accounts : Blogger (D) :- 0 : No , 1 : Yes
#
# 134 . Your accounts : Google App Engine (D) :- 0 : No , 1 : Yes
#
# 135 . Your accounts : Google Docs (D) :- 0 : No , 1 : Yes
#
# 136 . Your accounts : Google Finance (D) :- 0 : No , 1 : Yes
#
# 137 . Your accounts : Google Maps (D) :- 0 : No , 1 : Yes
#
# 138 . Your accounts : Google Spreadsheets (D) :- 0 : No , 1 : Yes
#
# 139 . Your accounts : Google Voice (D) :- 0 : No , 1 : Yes
#
# 140 . Your accounts : Google mail (D) :- 0 : No , 1 : Yes
#
# 141 . Your accounts : Picasa Web Albums (D) :- 0 : No , 1 : Yes
#
# 142 . Your accounts : YouTube (D) :- 0 : No , 1 : Yes
#
# 143 . Your accounts : YouTube usernames (D) :- 0 : No , 1 : Yes
#
# 144 . Your accounts : access all Google services (S) :- 0 : No , 1 : Yes
#
# 145 . Your accounts : access other Google services (D) :- 0 : No , 1 : Yes
#
# 146 . Your accounts : act as an account authenticator (D) :- 0 : No , 1 : Yes
#
# 147 . Your accounts : act as the AccountManagerService (S) :- 0 : No , 1 : Yes
#
# 148 . Your accounts : contacts data in Google accounts (D) :- 0 : No , 1 : Yes
#
# 149 . Your accounts : discover known accounts (S) :- 0 : No , 1 : Yes
#
# 150 . Your accounts : manage the accounts list (D) :- 0 : No , 1 : Yes
#
# 151 . Your accounts : read Google service configuration (S) :- 0 : No , 1 : Yes
#
# 152 . Your accounts : use the authentication credentials of an account (D) :- 0 : No , 1 : Yes
#
# 153 . Your accounts : view configured accounts (S) :- 0 : No , 1 : Yes
#
# 154 . Your location : access extra location provider commands (S) :- 0 : No , 1 : Yes
#
# 155 . Your location : coarse (network-based) location (D) :- 0 : No , 1 : Yes
#
# 156 . Your location : fine (GPS) location (D) :- 0 : No , 1 : Yes
#
# 157 . Your location : mock location sources for testing (D) :- 0 : No , 1 : Yes
#
# 158 . Your messages : Read Email attachments (D) :- 0 : No , 1 : Yes
#
# 159 . Your messages : Send Gmail (S) :- 0 : No , 1 : Yes
#
# 160 . Your messages : edit SMS or MMS (D) :- 0 : No , 1 : Yes
#
# 161 . Your messages : modify Gmail (D) :- 0 : No , 1 : Yes
#
# 162 . Your messages : read Gmail (D) :- 0 : No , 1 : Yes
#
# 163 . Your messages : read Gmail attachment previews (D) :- 0 : No , 1 : Yes
#
# 164 . Your messages : read SMS or MMS (D) :- 0 : No , 1 : Yes
#
# 165 . Your messages : read instant messages (D) :- 0 : No , 1 : Yes
#
# 166 . Your messages : receive MMS (D) :- 0 : No , 1 : Yes
#
# 167 . Your messages : receive SMS (D) :- 0 : No , 1 : Yes
#
# 168 . Your messages : receive WAP (D) :- 0 : No , 1 : Yes
#
# 169 . Your messages : send SMS-received broadcast (S) :- 0 : No , 1 : Yes
#
# 170 . Your messages : send WAP-PUSH-received broadcast (S) :- 0 : No , 1 : Yes
#
# 171 . Your messages : write instant messages (D) :- 0 : No , 1 : Yes
#
# 172 . Your personal information : add or modify calendar events and send email to guests (D) :- 0 : No , 1 : Yes
#
# 173 . Your personal information : choose widgets (S) :- 0 : No , 1 : Yes
#
# 174 . Your personal information : read Browser's history and bookmarks (D) :- 0 : No , 1 : Yes
#
# 175 . Your personal information : read calendar events (D) :- 0 : No , 1 : Yes
#
# 176 . Your personal information : read contact data (D) :- 0 : No , 1 : Yes
#
# 177 . Your personal information : read sensitive log data (D) :- 0 : No , 1 : Yes
#
# 178 . Your personal information : read user defined dictionary (D) :- 0 : No , 1 : Yes
#
# 179 . Your personal information : retrieve system internal state (S) :- 0 : No , 1 : Yes
#
# 180 . Your personal information : set alarm in alarm clock (S) :- 0 : No , 1 : Yes
#
# 181 . Your personal information : write Browser's history and bookmarks (D) :- 0 : No , 1 : Yes
#
# 182 . Your personal information : write contact data (D) :- 0 : No , 1 : Yes
#
# 183 . Your personal information : write to user defined dictionary (S) :- 0 : No , 1 : Yes
#
# 184 . Class :- 0 : Benign , 1 : Malware

# %% [markdown]
# Important packages to be imported

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Mount the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Load the dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/ML Classification/Data & Resources/ANDRIOD AUTHENTICITY PREDICTION (1).csv')
df.head()
# Out:
#                               App                                   Package  \
# 0         Canada Post Corporation                    com.canadapost.android
# 1                       Word Farm                 com.realcasualgames.words
# 2            Fortunes of War FREE                        fortunesofwar.free
# 3  Better Keyboard: Avatar Purple  com.cc.betterkeyboard.skins.avatarpurple
# 4                      Boxing Day                indiaNIC.android.BoxingDay
#
#            Category                                        Description  \
# 0          Business  Canada Post Mobile App gives you access to som...
# 1    Brain & Puzzle  Speed and strategy combine in this exciting wo...
# 2    Cards & Casino  Fortunes of War is a fast-paced, easy to learn...
# 3  Libraries & Demo  Skin for Better Keyboard featuring a glossy fe...
# 4         Lifestyle  Boxing Day by Christopher Jaymes<p>Based on a ...
#
#    Rating  Number of ratings  Price  \
# 0     3.1                 77   0.00
# ...

# %%
df.shape
# Out:
# (29999, 184)

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 184 columns):
#  #    Column                                                                                  Non-Null Count  Dtype
# ---   ------                                                                                  --------------  -----
#  0    App                                                                                     29998 non-null  object
#  1    Package                                                                                 29999 non-null  object
#  2    Category                                                                                29999 non-null  object
#  3    Description                                                                             29996 non-null  object
#  4    Rating                                                                                  29999 non-null  float64
# ...

# %% [markdown]
# As from the above we can see that there are some columns with the null values

# %%
col_with_null = []
for col in df.columns:
    if(df[col].isnull().values.any() or df[col].values.any() == " "):
        col_with_null.append(col)

# %%
col_with_null
# Out:
# ['App', 'Description', 'Related apps', 'Dangerous permissions count']

# %%
len(col_with_null)
# Out:
# 4

# %% [markdown]
# From the above we can see that, there are 4 colmns with the null values

# %%
for col in col_with_null:
    percentage  = df[col].isna().sum()*100/ len(df)
    print('Null value percentage for ',col ,'is ',percentage)
# Out:
# Null value percentage for  App is  0.0033334444481482716
# Null value percentage for  Description is  0.010000333344444815
# Null value percentage for  Related apps is  2.516750558351945
# Null value percentage for  Dangerous permissions count is  0.6800226674222474

# %% [markdown]
# So, from the baove analysis we can say that null values are very low when compared to the size of the dataset. So, we can simply drop the null values.

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (29240, 184)

# %% [markdown]
# Let's check for duplicated values in tha dataframe

# %%
df.duplicated().sum()
# Out:
# 2654

# %% [markdown]
# Here we can see that there are 2654 rows with the duplicated values. So, let's drop them.

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (26586, 184)

# %%
df.describe()
# Out:
#              Rating  Number of ratings         Price  \
# count  26586.000000       2.658600e+04  26586.000000
# mean       3.564493       5.370046e+03      0.599750
# std        1.380888       4.371014e+04      3.306346
# min        0.000000       0.000000e+00      0.000000
# 25%        3.300000       4.000000e+00      0.000000
# 50%        4.000000       4.100000e+01      0.000000
# 75%        4.400000       5.210000e+02      0.000000
# max        5.000000       1.908590e+06    158.070000
#
#        Dangerous permissions count  Safe permissions count  \
# count                 26586.000000            26586.000000
# mean                      3.035733                1.321447
# std                       2.993178                1.495085
# min                       0.000000                0.000000
# 25%                       1.000000                0.000000
# 50%                       2.000000                1.000000
# 75%                       4.000000                2.000000
# ...

# %%
col_with_all_zeros=[]
for col in df.describe().columns:
    if df[col].quantile(0.5)==0 and df[col].quantile(0.75)==0 and df[col].max()==0 :
        col_with_all_zeros.append(col)

# %%
col_with_all_zeros
# Out:
# ['Default : Access all system downloads (S)',
#  'Default : Modify Google service configuration (S)',
#  'Default : access to passwords for Google accounts (S)',
#  'Default : act as an account authenticator (S)',
#  'Default : coarse (network-based) location (S)',
#  'Default : discover known accounts (S)',
#  'Default : full Internet access (S)',
#  'Default : mock location sources for testing (S)',
#  'Default : modify/delete USB storage contents modify/delete SD card contents (S)',
#  'Default : permanently disable device (S)',
#  'Default : read instant messages (S)',
#  'Default : reset system to factory defaults (S)',
#  'Default : run in factory test mode (S)',
#  'Default : set wallpaper size hints (S)',
#  'Default : start IM service (S)',
#  'Default : write contact data (S)',
#  'Default : write instant messages (S)',
#  'Network communication : download files without notification (S)',
#  'System tools : change background data usage setting (S)',
# ...

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
len(col_with_all_zeros)
# Out:
# 22

# %% [markdown]
# From the above we can conclude that there are 22 columns with almost with zeros, which brings no value to the prediction. Let's drop that columns from the dataset.

# %%
for col in col_with_all_zeros:
    df.drop(col,inplace=True,axis=1)

# %%
df.shape
# Out:
# (26586, 162)

# %%
cat_feature_col = [col for col in df.columns if df[col].dtype == 'object']

# %%
for col in cat_feature_col:
    print(col, '- ',df[col].nunique());
# Out:
# App -  22176
# Package -  22815
# Category -  30
# Description -  22997
# Related apps -  23864

# %% [markdown]
# From the above we can see that only the Catogory featute has less unique values i.e 30 compared to the other categorical features. Lets explore the Category column in breif.

# %% [markdown]
# **UNIVARIATE AND MULTIVARIATE ANALYSIS**

# %%
from numpy.lib.function_base import rot90
plt.figure(figsize=(12,5),dpi=200)
sns.countplot(df['Category'])
plt.xlabel("App Categroy")
plt.ylabel("Number of Apps")
plt.xticks(rotation=90)
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# From the above plot we can say that, Entertainment related apps are the most preferred one compared to the other types of apps, followed by Travel related apps.
# The least downloaded of installed app among the 30 other categorical apps is Weather app.

# %% [markdown]
# Lets's explore target variable

# %%
df['Class'].value_counts()
# Out:
# 1    17592
# 0     8994
# Name: Class, dtype: int64

# %% [markdown]
# Let's find the percentage of BENIGN and MALWARE using pie plot

# %%
explode = [0.2]
plt.figure(figsize=(7,4),dpi=200)
plt.pie(df['Class'].value_counts(),labels=['MALWARE','GENUINE'],shadow=True,autopct='%1.1f%%')
plt.show();

# %% [markdown]
# 1) From the above plot we can see that Target variable is not Uniformly distributed.
#
# 2) About 67% of the apps are Malware.

# %%
rating = df.groupby('Category')[['Rating','Price']].mean().round(2)

rating.sort_values(by='Rating', ascending=False,inplace=True)
rating.reset_index(inplace=True)

# %%
rating
# Out:
#              Category  Rating  Price
# 0             Weather    3.97   1.08
# 1        Productivity    3.96   0.71
# 2             Finance    3.93   0.11
# 3       Communication    3.89   0.26
# 4               Tools    3.84   0.71
# 5      Cards & Casino    3.80   0.19
# 6              Racing    3.78   0.53
# 7    News & Magazines    3.75   0.15
# 8     Arcade & Action    3.75   0.51
# 9      Brain & Puzzle    3.74   0.23
# 10       Sports Games    3.74   0.71
# 11     Transportation    3.74   0.79
# 12      Media & Video    3.68   0.55
# 13          Education    3.66   0.70
# 14             Casual    3.65   0.25
# 15             Social    3.65   0.37
# 16             Comics    3.64   0.18
# 17   Libraries & Demo    3.60   0.01
# 18   Health & Fitness    3.59   0.40
# 19      Music & Audio    3.57   0.52
# 20           Shopping    3.54   0.27
# 21     Travel & Local    3.54   1.56
# 22        Photography    3.48   0.45
# 23             Sports    3.47   1.12
# ...

# %%
plt.figure(figsize=(3,4),dpi=200)
x=df['Rating']
y=df['Category']
sns.barplot(rating.Rating,rating.Category)
plt.xlabel('Rating')
plt.ylabel('App Category')
plt.yticks(fontsize=5)
plt.title('Category vs Rating')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# 1) From the above we can say that, even though weather is the least downloaded but it is  the most rated app.
#
# 2) Followed by Productivity and the least followed app is Mediacal related app.
#
# 3) The most downloaded app Entertainment is almost the least rated one which is the 3rd from the bottom.1

# %% [markdown]
# w.r.t price of the app

# %%
plt.figure(figsize=(5,2),dpi=200)
sns.barplot(x=rating.Rating,y=rating.Price)
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.title('Price vs Rating')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# 1) From the above plot we can conclude that the app which has the lower rating has the highest price, followed by the highest rated app.
#
# 2) But from the graph it is clear that the price of the app which is highly rated is just 25% of the price of the app which is lowest in rating.

# %%
plt.figure(figsize=(6,3),dpi=200)
sns.barplot(df.Category,df['Safe permissions count'])
plt.xticks(rotation=90,fontsize=7)
plt.yticks(fontsize=7)
plt.title('Category vs Safe Counts')
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# 1) From the above plot we can that the numbe of safe permissions when the app was installed is high is Social apps where as the count is less for Personalization.
#
# 2) Here can should be taken in personalization which stores our personal data has the minimum number of Safe permission count.

# %%
plt.figure(figsize=(5,2),dpi=200)
sns.barplot(x=rating.Category,y=rating.Price)
plt.xticks(rotation=90,fontsize=7)
plt.yticks(fontsize=7)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.title('Category vs Price')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Conclusion From EDA w.r.t only features
#
# 1) From the above plot we can conclude that the app which has the lower rating that is (Medical) has the highest price, and the app with the highlr rated(Weather) as the lowest price.
#
# 2) But from the graph it is clear that the price of the app which is highly rated is just 25% of the price of the app which is lowest in rating.
#
# 3) Price,category and rating are inter related i.e inversely praportional to each other [ Price = k * (1/Rating)]
#
# 4) We can draw differnt conclusion from all the baove graphs, which are as follows:-
#
#     MOST DOWNLOADED
#
#     a) Most downloaded app is Entertainment
#
#     b) Least downloaded app is Weather.
#
#     MOST RATED
#
#     c) Highest rated app is Weather, even though it is a least downloaded.
#
#     d) Lowest rated app is Medical.
#
#     PRICE
#
#     a) Price is high for Mediacl app though it's a low rated
#
#     b) Weather related app has the lowest price, but rated high.
#
#     SAFE PERMISSION
#
#     a) The numbe of safe permissions when the app was installed is high is Social apps where as the count is less for Personalization.
#
#     b) Here can should be taken in personalization which stores our personal data has the minimum number of Safe permission count.

# %% [markdown]
# # Let's explore EDA w.r.t target variable

# %%
num_feat_col = [ col for col in df.describe().columns if df[col].nunique()>2]

# %%
num_feat_col
# Out:
# ['Rating',
#  'Number of ratings',
#  'Price',
#  'Dangerous permissions count',
#  'Safe permissions count']

# %%
for col in num_feat_col:
    plt.figure()
    sns.distplot(df[col],kde=True)
    
    plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# From all the above distribution plots we can say that no numerical feature with unique value greater than 2 is normally distributed, So care should be taken for all these features in Feature Engineering.

# %%
cat_feature_col
# Out:
# ['App', 'Package', 'Category', 'Description', 'Related apps']

# %%
df['Price'].describe()
# Out:
# count    26586.000000
# mean         0.599750
# std          3.306346
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        158.070000
# Name: Price, dtype: float64

# %% [markdown]
# From the above graphs we  can say that all the numerical features are almost evenly distributed wrt to the target variable (Class) and we can see the up to 75% of prices are almost zeros and the price of the app started to increase above 75%. So, it's better convert the price to categorical Variable.

# %%
df['Price'] = df['Price'].apply(lambda x : 1 if x>0 else 0)

# %%
sns.countplot(x='Price',hue='Class',data=df)
plt.show()

# %% [markdown]
# 1) Here 0 indicate 'Free/Un-paid' apps and 1 indicates 'Paid' apps.
#
# 2) The apps which are paid has no Genuine apps all the apps belongs to malware which is the category where customer was looted.

# %%
cat_feature_col
# Out:
# ['App', 'Package', 'Category', 'Description', 'Related apps']

# %%
df[cat_feature_col].describe()
# Out:
#                 App       Package       Category  \
# count         26586         26586          26586
# unique        22176         22815             30
# top     Tic Tac Toe  com.jb.gosms  Entertainment
# freq             44             6           2458
#
#                                               Description  \
# count                                               26586
# unique                                              22997
# top     Phrasebook and Translator contains all the ess...
# freq                                                   27
#
#                   Related apps
# count                    26586
# unique                   23864
# top     {com.openkava.spinpic}
# freq                        37

# %%
for col in cat_feature_col:
    print(col, '- ',df[col].nunique());
# Out:
# App -  22176
# Package -  22815
# Category -  30
# Description -  22997
# Related apps -  23864

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='Category',hue='Class',data=df)
plt.xticks(rotation=90,fontsize=7)
plt.show()

# %% [markdown]
# From the above plot, we can say that:-
#
# 1) Most Malware app is the Entertainment app which is also the most downloaded app, and the least malware is the Libraries and demo app followed by Weather app which is the highy rated app.
#
# 2) Most Bengin app is Casual app followed by Enatertainment, Barin & puzzle and communication which are almost on same bar.

# %%
df['Description']
# Out:
# 0        Canada Post Mobile App gives you access to som...
# 1        Speed and strategy combine in this exciting wo...
# 2        Fortunes of War is a fast-paced, easy to learn...
# 3        Skin for Better Keyboard featuring a glossy fe...
# 5        Ms Claus Live Wallpaper<p>Find more Free apps ...
#                                ...
# 29993    Make check deposits to your FORUM Credit Union...
# 29994    Beechwood is an Android hotel app for guests, ...
# 29995    Explosive Tower Defense!<p>Top Tower Defense G...
# 29997    Key features of this App: <br>1. View photos o...
# 29998    A ball sits in a flat tray containing one or m...
# Name: Description, Length: 26586, dtype: object

# %%
df['Related apps']
# Out:
# 0        {com.adaffix.pub.ca.android, com.kevinquan.gas...
# 1        {air.com.zubawing.FastWordLite, com.joybits.do...
# 2        {com.kevinquan.condado, hu.monsta.pazaak, net....
# 3        {eu.gdumoulin.betterandroid.skins.transparent....
# 5        {tmc.christmassanta.livewallpaper, tmc.winterh...
#                                ...
# 29993    {com.forumcu.cuonline, com.msi.bktest, com.qua...
# 29994    {com.bluewaterpages, com.travelconnection.luxu...
# 29995    {com.entwicklerx.swampdefense, com.digimentgam...
# 29997    {com.hyxen.app.NewTaipeiTravel, j2ab.android.t...
# 29998    {com.twistedmirror.alberiplus, com.freesoul.Mo...
# Name: Related apps, Length: 26586, dtype: object

# %%
df['App_count'] = df['Related apps'].apply(lambda x : len(x.split(',')))

# %%
df['App_count']
# Out:
# 0        4
# 1        4
# 2        4
# 3        4
# 5        4
#         ..
# 29993    4
# 29994    4
# 29995    4
# 29997    4
# 29998    4
# Name: App_count, Length: 26586, dtype: int64

# %%
df['App_count'].nunique()
# Out:
# 4

# %%
df['App_count'].value_counts()
# Out:
# 4    25681
# 1      375
# 2      297
# 3      233
# Name: App_count, dtype: int64

# %% [markdown]
# From the above we can say that each category app has related apps with minimum of 1 and maxmium of 4 and max of apps has 4 realated apps and min of 3 related apps

# %%
tab = pd.crosstab(df['Category'],df['App_count'])

# %%
tab
# Out:
# App_count           1   2   3     4
# Category
# Arcade & Action     6   1   3  1625
# Books & Reference  35  39  24  1638
# Brain & Puzzle     11  13  11  1576
# Business            7  10   8   866
# Cards & Casino     12   8   9   736
# Casual              7  10   9  1417
# Comics             15   8  14   523
# Communication       3   3   1   979
# Education           6   7   7  1202
# Entertainment      48  47  35  2328
# Finance            11  14  12   948
# Health & Fitness    4   5   2   939
# Libraries & Demo   79  49  26   396
# Lifestyle          10  11   4  1249
# Media & Video       7   3   6   699
# Medical             3   1   5   239
# Music & Audio       1   4   3   444
# News & Magazines    6   3   3   403
# Personalization    15  11  13  1359
# Photography        25   5   9   223
# Productivity        1   0   0   593
# Racing              3   6   6   235
# Shopping            4   5   2   321
# Social             10   2   5   327
# Sports             11   2   1   562
# ...

# %%
grp = df.groupby('Category')[['App_count']].sum()

grp.sort_values('App_count',ascending=False)
grp.reset_index(inplace=True)

# %%
grp
# Out:
#              Category  App_count
# 0     Arcade & Action       6517
# 1   Books & Reference       6737
# 2      Brain & Puzzle       6374
# 3            Business       3515
# 4      Cards & Casino       2999
# 5              Casual       5722
# 6              Comics       2165
# 7       Communication       3928
# 8           Education       4849
# 9       Entertainment       9559
# 10            Finance       3867
# 11   Health & Fitness       3776
# 12   Libraries & Demo       1839
# 13          Lifestyle       5040
# 14      Media & Video       2827
# 15            Medical        976
# 16      Music & Audio       1794
# 17   News & Magazines       1633
# 18    Personalization       5512
# 19        Photography        954
# 20       Productivity       2373
# 21             Racing        973
# 22           Shopping       1304
# 23             Social       1337
# 24             Sports       2266
# 25       Sports Games       1142
# 26              Tools       4762
# ...

# %%
grp.groupby('Category').mean().sort_values('App_count')[['App_count']].plot(kind='bar',figsize=(15,5))
plt.xticks(rotation=90,fontsize=10)
plt.title('Category vs Realted_app_count')
plt.show()

# %%
plt.figure(figsize=(6,3),dpi=200)
sns.barplot(x='Category',y='App_count',data=grp)
plt.xticks(rotation=90,fontsize=7)
plt.title('Category vs Realted_app_count')
plt.show()

# %% [markdown]
# From the baove we can say  that Entertainment(which is the most downloaded) app has the most of the related apps of 9559 apps and the app with the lowest related is Weather(which is highly rated) with the 595 apps.

# %% [markdown]
# Now as we got data from the description and Related apps so let us drop them from the dataset

# %%
df.drop(['App','Package','Description','Related apps'],axis=1,inplace=True)

# %% [markdown]
# ***Lets Check For Outliners***

# %%
for col in num_feat_col:
  sns.boxplot(df[col])
  plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# Lets Check For Coorelation and Multicoliniarity

# %%
df.corr()
# Out:
#                                                       Rating  \
# Rating                                              1.000000
# Number of ratings                                   0.068698
# Price                                              -0.287123
# Dangerous permissions count                         0.084872
# Safe permissions count                              0.121522
# ...                                                      ...
# Your personal information : write Browser's his...  0.023468
# Your personal information : write contact data (D)  0.023032
# Your personal information : write to user defin...  0.016559
# Class                                              -0.208819
# App_count                                           0.095703
#
#                                                     Number of ratings  \
# Rating                                                       0.068698
# Number of ratings                                            1.000000
# ...

# %% [markdown]
# From the above Coorelation matrix it is very difficult for us to analysize what are features having high coorelation. So let us define a function to check this.

# %%
def coorelation(dataset,threshold):
  col_corr = []
  corr_matrix = dataset.corr()
  for i in range(len(corr_matrix.columns)):
    for j in range(i):
      if abs(corr_matrix.iloc[j,i])>threshold:
        col_name = corr_matrix.columns[i]
        col_corr.append(col_name)
  return col_corr

# %%
correlation_colums_60 = coorelation(df,0.6)
len(correlation_colums_60)
# Out:
# 29

# %%
correlation_colums_50 = coorelation(df,0.5)
len(correlation_colums_50)
# Out:
# 54

# %%
correlation_colums_70 = coorelation(df,0.7)
len(correlation_colums_70)
# Out:
# 17

# %%
correlation_colums_70
# Out:
# ['Safe permissions count',
#  'Default : Voice Search Shortcuts (S)',
#  'Default : access the cache filesystem (S)',
#  'Default : update component usage statistics (S)',
#  'Development tools : make all background applications close (D)',
#  'System tools : bluetooth administration (D)',
#  'System tools : write subscribed feeds (D)',
#  'System tools : write sync settings (D)',
#  'Your accounts : Google Spreadsheets (D)',
#  'Your accounts : YouTube usernames (D)',
#  'Your accounts : manage the accounts list (D)',
#  'Your messages : Send Gmail (S)',
#  'Your messages : read SMS or MMS (D)',
#  'Your personal information : read calendar events (D)',
#  'Your personal information : retrieve system internal state (S)',
#  "Your personal information : write Browser's history and bookmarks (D)",
#  'Your personal information : write to user defined dictionary (S)']

# %% [markdown]
# From the above we can say that:-
#
# 1) When threshold is 0.5 then there are  54 columns which are highly coorelated.
#
# 2) When threshold is 0.6 then there are  29 columns which are highly coorelated.
#
# 3) When threshold is 0.7 then there are  17 columns which are highly coorelated.
#
# So, let us choose 70% threshold and drop the features which are above it.

# %%
df.shape
# Out:
# (26586, 159)

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df_70 = df.copy()
df_70.shape
# Out:
# (26586, 159)

# %%
df_70.isna().sum().sum()
# Out:
# 0

# %%
for col in correlation_colums_70:
  df_70.drop(col,axis=1,inplace=True)

# %%
df_70[df_70['Class']==np.nan]
# Out:
# Empty DataFrame
# ...

# %%
thre_num_col = [col for col in df_70.describe().columns if df_70[col].nunique()>4]
thre_cat_col = [ col for col in df_70.columns if df_70[col].dtype=='object']

# %%
thre_num_col
# Out:
# ['Rating', 'Number of ratings', 'Dangerous permissions count']

# %%
for col in thre_num_col:
  print(df_70[col].nunique())
# Out:
# 42
# 5299
# 28

# %%
thre_cat_col
# Out:
# ['Category']

# %%
pip install statsmodels
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
def VIF(dataset):
  vif_df = pd.DataFrame()
  vif_df['Features'] = dataset.columns
  vif_df['VIF'] = [variance_inflation_factor(dataset.values,i) for i in range(dataset.shape[1])]
  return vif_df

# %% [markdown]
# As we have Category feature with 30 unique values. We have 2 methods to get rid of this:-
#
# 1) First is to get dummies but as we alreay have around 150 features so it's not a good idea to get more features from this.
#
# 2) Relace the Category with the mean of it wrt target variable. So it will be sacled up between 0 and 1

# %%
cat_mean = df_70.groupby('Category')['Class'].mean().to_dict()
df_70['Category'] = df_70['Category'].map(cat_mean)
print(df_70['Category'].head())
print(df_70['Category'].dtype)
# Out:
# 0    0.428732
# 1    0.659218
# 2    0.328105
# 3    0.165455
# 5    0.665951
# Name: Category, dtype: float64
# float64

# %%
df_70['Category'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# **FEATURE ENGINEERING**

# %%
from sklearn.preprocessing import StandardScaler

# %%
thre_num_col
# Out:
# ['Rating', 'Number of ratings', 'Dangerous permissions count']

# %%
list_num = ['Category','Rating', 'Number of ratings', 'Dangerous permissions count']

# %%
scaler = StandardScaler()

# %%
X = df_70.drop('Class',axis=1)
y = df_70['Class']

# %%
X.shape
# Out:
# (26586, 141)

# %%
X.head()
# Out:
#    Category  Rating  Number of ratings  Price  Dangerous permissions count  \
# 0  0.428732     3.1                 77      0                          7.0
# 1  0.659218     4.3                199      0                          3.0
# 2  0.328105     4.1                243      0                          1.0
# 3  0.165455     3.6               2589      0                          0.0
# 5  0.665951     4.5                 16      0                          3.0
#
#    Default : Access DRM content. (S)  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 5                                  0
#
#    Default : Access Email provider data (S)  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 5                                         0
#
# ...

# %%
y.isna().sum()
# Out:
# 0

# %% [markdown]
# Let' us define a function for the purpose of simpli

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## **1. LOGISTIC REGRESSION**

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
print('Training Score --',lr.score(X_train,y_train))
print('Test Score --',lr.score(X_test,y_test))
# Out:
# Training Score -- 0.7549369945457965
# Test Score -- 0.7508461827754795
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
from sklearn.metrics import confusion_matrix,plot_confusion_matrix,classification_report,precision_score,accuracy_score,recall_score,f1_score
from sklearn.metrics import roc_curve,auc
from sklearn import metrics

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[1004,  770],
#        [ 555, 2989]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.57      0.60      1774
#            1       0.80      0.84      0.82      3544
#
#     accuracy                           0.75      5318
#    macro avg       0.72      0.70      0.71      5318
# weighted avg       0.74      0.75      0.75      5318

# %%
plot_confusion_matrix(lr,X_test,y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
#logit_results = (accuracy_score(y_test,y_pred),precision_score(y_test,y_pred)recall_score(y_test,y_pred))
print('Accuracy Score - ',accuracy_score(y_test,y_pred))
print('Precision Score - ',precision_score(y_test,y_pred))
print('recall Score - ',recall_score(y_test,y_pred))
print('f1 Score - ',f1_score(y_test,y_pred))
print('Sensitivity - ',cm[1,1]/(cm[1,0]+cm[1,1]))
print('Specificity - ',cm[0,0]/(cm[0,0]+cm[0,1]))
# Out:
# Accuracy Score -  0.7508461827754795
# Precision Score -  0.7951582867783985
# recall Score -  0.8433972911963883
# f1 Score -  0.8185677118992194
# Sensitivity -  0.8433972911963883
# Specificity -  0.5659526493799324

# %% [markdown]
# Receiver Operator characteristic curve

# %%
def draw_roc( actual, probs ):
    fpr, tpr, thresholds = metrics.roc_curve( actual, probs,drop_intermediate = False )
    auc_score = metrics.roc_auc_score( actual, probs )
    plt.figure(figsize=(6, 4))
    plt.plot( fpr, tpr, label='ROC curve (area = %0.2f)' % auc_score )
    plt.plot([0,1], [0,1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()
    return fpr, tpr, thresholds

# %%
draw_roc(y_test,y_pred)
# Out:
# (array([0.        , 0.43404735, 1.        ]),
#  array([0.        , 0.84339729, 1.        ]),
#  array([2, 1, 0]))

# %% [markdown]
# From the above analysis we can say that our model has performed well so far with the accuracy and AUC a follows:-
#
# 1) Accuracy Score  -  75%
#
# 2) Precision Score -  79.5%
#
# 3) recall Score    -  84.3%
#
# 4) f1 Score        -  81.8%
#
# 3) Sensitivity(tpr) - 84.5%
#
# 4) Specificity(fpr) - 56.5%

# %% [markdown]
# ## **2. SUPPORT VECTOR MACHINE**

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
svc_model = SVC()
svc_model.fit(X_train,y_train)
y_pred_model = svc_model.predict(X_test)
cm_svc = confusion_matrix(y_test,y_pred_model)
cm_svc

print('*'*30)
print()

print(classification_report(y_test,y_pred_model))
print('*'*30)
print()

print(plot_confusion_matrix(svc_model,X_test,y_test))
print('*'*30)
print()

print('Accuracy Score - ',accuracy_score(y_test,y_pred_model))
print('Precision Score - ',precision_score(y_test,y_pred_model))
print('recall Score - ',recall_score(y_test,y_pred_model))
print('f1 Score - ',f1_score(y_test,y_pred_model))
print('Sensitivity - ',cm_svc[1,1]/(cm_svc[1,0]+cm_svc[1,1]))
print('Specificity - ',cm_svc[0,0]/(cm_svc[0,0]+cm_svc[0,1]))

print('*'*30)
print()

draw_roc(y_test,y_pred_model)
# Out:
# ******************************
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.57      0.60      1774
#            1       0.79      0.84      0.82      3544
#
#     accuracy                           0.75      5318
#    macro avg       0.72      0.70      0.71      5318
# weighted avg       0.74      0.75      0.74      5318
#
# ******************************
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# ...
# ******************************
#
# Accuracy Score -  0.7482136141406543
# Precision Score -  0.7947072975140337
# recall Score -  0.838882618510158
# f1 Score -  0.816197666437886
# ...

# %% [markdown]
# From the above SVC model we can see that our model is predicting quit well in almost al the cases except the specificity which is fpr. Which is also almost similar to our logistic regression model. so let us explore tree based model also with GridSearchCV for better performance of the model

# %% [markdown]
# ## **3. KNN CLASSIFIER**

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier()
accuracy = []
for i in range(1,31):
  knn_model = KNeighborsClassifier(n_neighbors=i)
  knn_model.fit(X_train,y_train)
  y_pred_knn = knn_model.predict(X_test)
  accuracy.append(accuracy_score(y_test,y_pred_knn))

# %%
plt.figure(figsize=(7,2),dpi=200)
plt.plot(np.arange(1,31),accuracy,marker='.')
plt.xlabel('n_neighbours')
plt.ylabel('Accuracy')
plt.title('KNN vs Accuracy')
plt.show()

# %% [markdown]
# From the above graph we can say that for the n_neigbours of 7 and 19 the accuracy is around 25 so its better to choose one them and build a model.

# %%
knn_model_final = KNeighborsClassifier(n_neighbors=7)
knn_model_final.fit(X_train,y_train)
y_pred_knn_final = knn_model_final.predict(X_test)

print('*'*10,'CONFUSION MATRIX','*'*10)
print()



cm_knn = confusion_matrix(y_test,y_pred_knn_final)
print(cm_knn)

print('*'*10,'CLASSIFICATION REPORT','*'*10)
print()

print(classification_report(y_test,y_pred_knn_final))
plt.show();

print('*'*10,'PLOT CONFUSION MATRIX','*'*10)
print()

print(plot_confusion_matrix(knn_model_final,X_test,y_test))
plt.show();


print('*'*10,'MODEL EVALUATION METRICES','*'*10)
print()

print('Accuracy Score - ',accuracy_score(y_test,y_pred_knn_final))
print('Precision Score - ',precision_score(y_test,y_pred_knn_final))
print('recall Score - ',recall_score(y_test,y_pred_knn_final))
print('f1 Score - ',f1_score(y_test,y_pred_knn_final))
print('Sensitivity - ',cm_knn[1,1]/(cm_knn[1,0]+cm_knn[1,1]))
print('Specificity - ',cm_knn[0,0]/(cm_knn[0,0]+cm_knn[0,1]))

print('*'*30)
print()

draw_roc(y_test,y_pred_knn_final)
# Out:
# ********** CONFUSION MATRIX **********
#
# [[1076  698]
#  [ 643 2901]]
# ********** CLASSIFICATION REPORT **********
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.61      0.62      1774
#            1       0.81      0.82      0.81      3544
#
#     accuracy                           0.75      5318
#    macro avg       0.72      0.71      0.71      5318
# weighted avg       0.75      0.75      0.75      5318
#
# ********** PLOT CONFUSION MATRIX **********
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# ...
# ********** MODEL EVALUATION METRICES **********
#
# Accuracy Score -  0.747837532907108
# ...

# %% [markdown]
# From the above analysis we can see that KNN alogithm is perform a margin better compared to the previous model. We can see increase in Specificity and AUC score campared to the previous models.

# %% [markdown]
# ## **4. DECISION TREE CLASSIFIER**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

param_grid = {
 'max_depth': range(5, 15, 5),
 'min_samples_leaf': range(50, 150, 50),
 'min_samples_split': range(50, 150, 50),
 'criterion': ["entropy", "gini"]
}
tree_model =DecisionTreeClassifier(random_state=101)

tree_model = GridSearchCV(tree_model,param_grid=param_grid,cv=5,return_train_score=True,verbose=1)

tree_model.fit(X_train,y_train)

print('Decision Tree Classifier Best Score {}  Best Params{}'.format(tree_model.best_score_,tree_model.best_params_))
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Decision Tree Classifier Best Score 0.8005450949140578 Best Params{'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 100, 'min_samples_split': 50}

# %%
tree_model_final =DecisionTreeClassifier(criterion='entropy',max_depth=10,min_samples_leaf=100,min_samples_split=50,random_state=101)
tree_model_final.fit(X_train,y_train)
y_pred_tree_final = tree_model_final.predict(X_test)

print('*'*10,'CONFUSION MATRIX','*'*10)
print()



cm_tree = confusion_matrix(y_test,y_pred_tree_final)
print(cm_tree)
print()


print('*'*10,'CLASSIFICATION REPORT','*'*10)
print()

print(classification_report(y_test,y_pred_tree_final))
plt.show();

print('*'*10,'PLOT CONFUSION MATRIX','*'*10)
print()

print(plot_confusion_matrix(tree_model_final,X_test,y_test))
plt.show();


print('*'*10,'MODEL EVALUATION METRICES','*'*10)
print()

print('Accuracy Score - ',accuracy_score(y_test,y_pred_tree_final))
print('Precision Score - ',precision_score(y_test,y_pred_tree_final))
print('recall Score - ',recall_score(y_test,y_pred_tree_final))
print('f1 Score - ',f1_score(y_test,y_pred_tree_final))
print('Sensitivity - ',cm_tree[1,1]/(cm_tree[1,0]+cm_tree[1,1]))
print('Specificity - ',cm_tree[0,0]/(cm_tree[0,0]+cm_tree[0,1]))

print('*'*30)
print()

draw_roc(y_test,y_pred_tree_final)

print('*'*30)
print()

from sklearn.tree import plot_tree
fig = plt.figure(figsize=(5,3),dpi=200)
plt.title('Model Plot')
plot_tree(tree_model_final,feature_names=X.columns,filled=True);
# Out:
# ********** CONFUSION MATRIX **********
#
# [[1323  451]
#  [ 596 2948]]
#
# ********** CLASSIFICATION REPORT **********
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.75      0.72      1774
#            1       0.87      0.83      0.85      3544
#
#     accuracy                           0.80      5318
#    macro avg       0.78      0.79      0.78      5318
# weighted avg       0.81      0.80      0.80      5318
#
# ********** PLOT CONFUSION MATRIX **********
#
# ...
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# ********** MODEL EVALUATION METRICES **********
#
# Accuracy Score -  0.8031214742384355
# ...

# %% [markdown]
# 1) From the above Decision Tree Classifier we can say that it has performed really well in all the aspects,the best metrics values soo fat compared to the previous models. We have managed to acheive a AUC score of 79%.
#
#
# 2) So lets us explore Gradient and Boosting Classifier in order to know which model performs well on the given dataset.1

# %% [markdown]
# ## **5. Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=1)
# param_grid = {'max_depth': [4,8,10],'min_samples_leaf': range(100, 400, 200),
#               'min_samples_split': range(200, 500, 200),'n_estimators': [100,200, 300], 'max_features': [5, 10]}

param_grid = {
 'max_depth': range(5, 15, 5),
 'min_samples_leaf': range(50, 150, 50),
 'min_samples_split': range(50, 150, 50),
 'criterion': ["entropy", "gini"],
 'n_estimators': [100,200, 300,400], 'max_features': [5, 10,15,20]
}
rf_grid =GridSearchCV(rf,param_grid,cv=5,return_train_score=True,verbose=1)
rf_grid.fit(X_train,y_train)
print ('Best Parameters: ', rf_grid.best_params_, ' \n')
print()
print ('Best Score: ', rf_grid.best_score_)
# Out:
# Fitting 5 folds for each of 256 candidates, totalling 1280 fits
# Best Parameters:  {'criterion': 'gini', 'max_depth': 10, 'max_features': 20, 'min_samples_leaf': 50, 'min_samples_split': 50, 'n_estimators': 400}
#
#
# Best Score:  0.7957023173774511

# %% [markdown]
# Now let us build a model with the best hyperparameters

# %%
rf_final =RandomForestClassifier(max_depth=10,n_estimators=400,criterion='gini',max_features=20,min_samples_leaf=50,min_samples_split=50,random_state=101)
rf_final.fit(X_train,y_train)
y_pred_rf_final = rf_final.predict(X_test)

print('*'*20,'CONFUSION MATRIX','*'*20)
print()
print()



cm_rf = confusion_matrix(y_test,y_pred_rf_final)
print(cm_rf)
print()
print()



print('*'*20,'CLASSIFICATION REPORT','*'*20)
print()
print()

print(classification_report(y_test,y_pred_rf_final))
plt.show();
print()

print('*'*20,'PLOT CONFUSION MATRIX','*'*20)
print()
print()

print(plot_confusion_matrix(rf_final,X_test,y_test))
plt.show();
print()


print('*'*20,'MODEL EVALUATION METRICES','*'*20)
print()
print()

print('Accuracy Score - ',accuracy_score(y_test,y_pred_rf_final))
print('Precision Score - ',precision_score(y_test,y_pred_rf_final))
print('recall Score - ',recall_score(y_test,y_pred_rf_final))
print('f1 Score - ',f1_score(y_test,y_pred_rf_final))
print('Sensitivity - ',cm_rf[1,1]/(cm_rf[1,0]+cm_rf[1,1]))
print('Specificity - ',cm_rf[0,0]/(cm_rf[0,0]+cm_rf[0,1]))
print()
print()

print('*'*30)
print()
print()

draw_roc(y_test,y_pred_rf_final)
print()
print('*'*30)
print()
# Out:
# ******************** CONFUSION MATRIX ********************
#
#
# [[1228  546]
#  [ 489 3055]]
#
#
# ******************** CLASSIFICATION REPORT ********************
#
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.69      0.70      1774
#            1       0.85      0.86      0.86      3544
#
#     accuracy                           0.81      5318
#    macro avg       0.78      0.78      0.78      5318
# weighted avg       0.80      0.81      0.80      5318
#
#
# ******************** PLOT CONFUSION MATRIX ********************
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# ...

# %% [markdown]
# From the above Random forest Classifier model we have acheived good accuracy of 81% and we have acheived better results in all the other evaluation metrics also we have obtained AUC score of 78%.
#
# But here there is a big lag in specificity and AUC score compared to the Decision tree classifier with a range of just 1 %.

# %% [markdown]
# ## **6. Gradient Boosting Classifier**

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
param_grid = {'learning_rate':[0.08, 0.8],'subsample':[0.3, 0.6],'max_depth': range(5, 15, 5),
 'min_samples_leaf': [20,30,40],
 'min_samples_split': range(50, 150, 50),
 'n_estimators': [100,200, 300,400]}
gb = GradientBoostingClassifier(random_state=1)
gb.grid = GridSearchCV(gb,param_grid,verbose=1,cv=3)
gb.grid.fit(X_train,y_train)
print('Best Score is ',gb.grid.best_score_,'/n')
print()
print('Best Params are ',gb.grid.best_params_)
# Out:
# Fitting 3 folds for each of 192 candidates, totalling 576 fits
# Best Score is  0.8090087193499161 /n
#
# Best Params are  {'learning_rate': 0.08, 'max_depth': 5, 'min_samples_leaf': 40, 'min_samples_split': 50, 'n_estimators': 100, 'subsample': 0.3}

# %%
gb_final =GradientBoostingClassifier(learning_rate=0.08,subsample=0.3,max_depth=5,n_estimators=100,min_samples_leaf=40,min_samples_split=50,random_state=101)
gb_final.fit(X_train,y_train)
y_pred_gb_final = gb_final.predict(X_test)

print('*'*20,'CONFUSION MATRIX','*'*20)
print()
print()



cm_gb = confusion_matrix(y_test,y_pred_gb_final)
print(cm_gb)
print()
print()



print('*'*20,'CLASSIFICATION REPORT','*'*20)
print()
print()

print(classification_report(y_test,y_pred_gb_final))
plt.show();
print()

print('*'*20,'PLOT CONFUSION MATRIX','*'*20)
print()
print()

print(plot_confusion_matrix(gb_final,X_test,y_test))
plt.show();
print()


print('*'*20,'MODEL EVALUATION METRICES','*'*20)
print()
print()

print('Accuracy Score - ',accuracy_score(y_test,y_pred_gb_final))
print('Precision Score - ',precision_score(y_test,y_pred_gb_final))
print('recall Score - ',recall_score(y_test,y_pred_gb_final))
print('f1 Score - ',f1_score(y_test,y_pred_gb_final))
print('Sensitivity - ',cm_gb[1,1]/(cm_gb[1,0]+cm_gb[1,1]))
print('Specificity - ',cm_gb[0,0]/(cm_gb[0,0]+cm_gb[0,1]))
print()
print()

print('*'*30)
print()
print()

draw_roc(y_test,y_pred_gb_final)
print()
print('*'*30)
print()
# Out:
# ******************** CONFUSION MATRIX ********************
#
#
# [[1426  348]
#  [ 617 2927]]
#
#
# ******************** CLASSIFICATION REPORT ********************
#
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.80      0.75      1774
#            1       0.89      0.83      0.86      3544
#
#     accuracy                           0.82      5318
#    macro avg       0.80      0.81      0.80      5318
# weighted avg       0.83      0.82      0.82      5318
#
#
# ******************** PLOT CONFUSION MATRIX ********************
#
#
# ...
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# ...

# %% [markdown]
# Soo far what are the models we have prepared, Gradiend Boosting Classifier has given us the best results which are as follows:-
#
# 1) We can observe that using Gradient Boosting Classifier our model classified 82% of class correctly.
#
# 2) With f1-score for Benign app is 75% and for Malware app is 86%.
#
# 3) Recall - Gradient Boosting Model can classify 80% of total benign apps correctly and 83% of total malware apps correctly.
#
# 4) Precision - Out of total predicted benign apps, 70% were correctly classified & out of total predicted malware apps, 89% were correctly classified.

# %%
X.columns
# Out:
# Index(['Category', 'Rating', 'Number of ratings', 'Price',
#        'Dangerous permissions count', 'Default : Access DRM content. (S)',
#        'Default : Access Email provider data (S)',
#        'Default : Access download manager. (S)',
#        'Default : Advanced download manager functions. (S)',
#        'Default : Audio File Access (S)',
#        ...
#        'Your messages : send WAP-PUSH-received broadcast (S)',
#        'Your personal information : add or modify calendar events and send email to guests (D)',
#        'Your personal information : choose widgets (S)',
#        'Your personal information : read Browser's history and bookmarks (D)',
#        'Your personal information : read contact data (D)',
#        'Your personal information : read sensitive log data (D)',
#        'Your personal information : read user defined dictionary (D)',
#        'Your personal information : set alarm in alarm clock (S)',
# ...

# %%
data = {'Features':list(X.columns),'Feature_Importance':gb_final.feature_importances_}
feature_imp_df = pd.DataFrame(data)
feature_imp_df.sort_values('Feature_Importance',ascending=False,inplace=True)

# %%
feature_imp_df_10 = feature_imp_df[feature_imp_df['Feature_Importance']>0.005]
feature_imp_df_10
# Out:
#                                               Features  Feature_Importance
# 0                                             Category            0.389779
# 2                                    Number of ratings            0.367193
# 3                                                Price            0.122988
# 1                                               Rating            0.024260
# 63      Network communication : view network state (S)            0.015744
# 4                          Dangerous permissions count            0.014797
# 134  Your personal information : read Browser's his...            0.006634
# 52            Hardware controls : control vibrator (S)            0.005211

# %%
#plt.figure(figsize=(4,2),dpi=200)
sns.barplot(y='Feature_Importance',x='Features',data=feature_imp_df_10)
plt.title('Feature Importance')
plt.xticks(rotation=90)
plt.show();

# %% [markdown]
# ## **CONCLUSION**

# %% [markdown]
# **MODEL**
#
# From all the above models, i have come up with the bossting model which performs in better predictions are as follows:-
#
# 1) Our model classified 82% of class correctly.
#
# 2) Precision - Out of total predicted benign apps, 70% were correctly classified & out of total predicted malware apps, 89% were correctly classified.
#
# 3) With the AUC score of 81%.
#
#
# **IMPORTANT FEATURES**
#
# a) The most important feature wrt predicting the target is Category followed by Number of ratings, price, ratings.
#
# **EDA**
#
# 1) The app which has the lower rating that is (Medical) has the highest price and also the malware, and the app with the higher rated(Weather) as the lowest price.
#
# 2) But from the graph it is clear that the price of the app which is highly rated is just 25% of the price of the app which is lowest in rating.
#
# 3) Price,category and rating are inter related i.e inversely praportional to each other [ Price = k * (1/Rating)]
#
# 4) From the above plots we can say that Entertainment(which is the most downloaded) app has the most of the related apps of 9559 apps and the app with the lowest related is Weather(which is highly rated) with the 595 apps
#
# 5) We can draw differnt conclusion from all the above graphs, which are as follows:-
#
# **MOST DOWNLOADED**
#
# a) Most downloaded app is Entertainment
#
# b) Least downloaded app is Weather.
#
# **MOST RATED**
#
# c) Highest rated app is Weather, even though it is a least downloaded.
#
# d) Lowest rated app is Medical.
#
# **PRICE**
#
# a) Price is high for Mediacl app though it's a low rated
#
# b) Weather related app has the lowest price, but rated high.
#
# **MALWARE AND GENUINE**
#
# a) Most Malware app is the Entertainment app which is also the most downloaded app, and the least malware is the Libraries and demo app followed by Weather app which is the highy rated app.
#
# b) Most Bengin app is Casual app followed by Enatertainment, Barin & puzzle and communication which are almost on same bar.

# %% [markdown]
# ##                                     **THANK YOU!!**
